# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('netflix_titles.csv')
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
df.head()
# it shows first N rows in the data(default N=5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail()
## it shows last N rows in the data(default N=5)
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df.shape
#It shows the total no. of rows and no. of columns of the dataframe.
# Out:
# (8807, 12)

# %%
df.size
#It show No. of total values(elements) in the dataset.
# Out:
# 105684

# %%
df.columns
#It show each Column Name.
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.dtypes
#It show the data-type of each column
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df.info()
#To show indexes, columns, data-types of each column, memory at once.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.duration.value_counts()
#In a column, it shows all the unique values with their count. It can be applied on a single column only.
# Out:
# 1 Season     1793
# 2 Seasons     425
# 3 Seasons     199
# 90 min        152
# 94 min        146
#              ...
# 16 min          1
# 186 min         1
# 193 min         1
# 189 min         1
# 191 min         1
# Name: duration, Length: 220, dtype: int64

# %%
df.country.unique()
#In a column, it shows all the unique values with their count. It can be applied on a single column only.
# Out:
# array(['United States', 'South Africa', nan, 'India',
#        'United States, Ghana, Burkina Faso, United Kingdom, Germany, Ethiopia',
#        'United Kingdom', 'Germany, Czech Republic', 'Mexico', 'Turkey',
#        'Australia', 'United States, India, France', 'Finland',
#        'China, Canada, United States',
#        'South Africa, United States, Japan', 'Nigeria', 'Japan',
#        'Spain, United States', 'France', 'Belgium',
#        'United Kingdom, United States', 'United States, United Kingdom',
#        'France, United States', 'South Korea', 'Spain',
#        'United States, Singapore', 'United Kingdom, Australia, France',
#        'United Kingdom, Australia, France, United States',
#        'United States, Canada', 'Germany, United States',
#        'South Africa, United States', 'United States, Mexico',
#        'United States, Italy, France, Japan',
#        'United States, Italy, Romania, United Kingdom',
#        'Australia, United States', 'Argentina, Venezuela',
# ...

# %%
df.nunique()
#It shows the total no. of unique values in the series.
# Out:
# show_id         8807
# type               2
# title           8807
# director        4528
# cast            7692
# country          748
# date_added      1767
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %% [markdown]
# Task. 1) Is there any Duplicate Record in this dataset ? If yes, then remove the duplicate records.

# %%
#it check row wise and detect the Duplicate rows
pd.set_option('display.max_rows',None)
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# Conclusion:No duplicated records are found.

# %% [markdown]
# Task. 2) Is there any Null Value present in any column ? Show with Heat-map.

# %%
data=df.isna()

#it show the count of  where Null value is present

# %%
sns.heatmap(data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Conclusion:We can see from above graph their are null values present in columns [director,cast,country,date added, duration]
#     in which director column has maximum no. of null valuess are present and apart
#     from director column other columns are less values.

# %% [markdown]
# Q. 3) How many Movies & TV Shows are in the dataset ? Show with Bar Graph.

# %%
type_count=df.groupby('type').type.count()  
type_count# to group all unique items of a columns and show their items
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
type_count.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='type'>

# %% [markdown]
# Conclusion: count of Movie are 6131 and TV Show are 2676.
#     From Graph also conclude that count of movies are more as compared to TV Shows.

# %% [markdown]
# Q. 4) For 'Midnight Mass', what is the Show Id and Who is the Director of this show ?

# %%
df.groupby('title').get_group( 'Midnight Mass')
# Out:
#   show_id     type          title       director  \
# 5      s6  TV Show  Midnight Mass  Mike Flanagan
#
#                                                 cast country  \
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...     NaN
#
#            date_added  release_year rating  duration  \
# 5  September 24, 2021          2021  TV-MA  1 Season
#
#                             listed_in  \
# 5  TV Dramas, TV Horror, TV Mysteries
#
#                                          description
# 5  The arrival of a charismatic young priest brin...

# %% [markdown]
# conclusion:show_id is s1060 and director of show  'Midnight Mass' is Mike Flanagan.

# %% [markdown]
# Q. 5) In which year the highest number of the TV Shows & Movies were released ? Show with Bar Graph.

# %%
counts_release_year=df['release_year'].value_counts()
counts_release_year.head()
# Out:
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
# Name: release_year, dtype: int64

# %%
plt.figure(figsize=(12,10))
counts_release_year.plot(kind='bar')
plt.xlabel('Release year of MOvies and Tv Shows')
# Out:
# <AxesSubplot:>

# %%
Conclusion:In year 2018 the highest number of the TV Shows & Movies were released

# %% [markdown]
# Q. 6) Show all the Movies that were released in year 2000.

# %%
df[(df['type']=='Movie') & (df['release_year']==2000)]
# Out:
#      show_id   type                                              title  \
# 180     s181  Movie                 The Nutty Professor II: The Klumps
# 350     s351  Movie                                      Space Cowboys
# 359     s360  Movie                       The Original Kings of Comedy
# 566     s567  Movie                                   Charlie's Angels
# 593     s594  Movie                                           Snow Day
# 779     s780  Movie                                  Battlefield Earth
# 952     s953  Movie                               The Whole Nine Yards
# 3472   s3473  Movie                        Rugrats in Paris: The Movie
# 4545   s4546  Movie             Monty Python: Before the Flying Circus
# 4723   s4724  Movie                                               Fiza
# 4956   s4957  Movie                        Phir Bhi Dil Hai Hindustani
# 5953   s5954  Movie                             Joseph: King of Dreams
# ...

# %% [markdown]
# Q. 7) Show only the Titles of all TV Shows that were released in India only.

# %%
df[(df['type']=='TV Show') & (df['country']=='India')]
# Out:
#      show_id     type                                          title  \
# 4         s5  TV Show                                   Kota Factory
# 39       s40  TV Show                                   Chhota Bheem
# 50       s51  TV Show                                  Dharmakshetra
# 66       s67  TV Show                  Raja Rasoi Aur Anya Kahaniyan
# 69       s70  TV Show                 Stories by Rabindranath Tagore
# 266     s267  TV Show                           The Creative Indians
# 297     s298  TV Show                                       Navarasa
# 876     s877  TV Show                                   Alma Matters
# 911     s912  TV Show                               Sab Jholmaal Hai
# 918     s919  TV Show                                 Lava Ka Dhaava
# 1093   s1094  TV Show                                    The Big Day
# 1227   s1228  TV Show                                  Bombay Begums
# 1282   s1283  TV Show                               Zindagi in Short
# ...

# %%
df[(df['type']=='TV Show') & (df['country']=='India')]['title'].head(2)
# Out:
# 4     Kota Factory
# 39    Chhota Bheem
# Name: title, dtype: object

# %% [markdown]
# Q. 8) Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ?

# %%
df.groupby('director').director.count().nlargest(10)
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Martin Scorsese           12
# Youssef Chahine           12
# Steven Spielberg          11
# Name: director, dtype: int64

# %%
df['director'].value_counts().head(10)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64

# %% [markdown]
# Q. 9) Show all the Records, where "Category is Movie and Type is Comedies" or "Country is United Kingdom".

# %%
df[(df['type']=='Movie') & (df['listed_in']=='Comedies') | (df['country']=='United Kingdom')].head(2)
# Out:
#    show_id     type                          title         director  \
# 8       s9  TV Show  The Great British Baking Show  Andy Devonshire
# 27     s28    Movie                      Grown Ups     Dennis Dugan
#
#                                                  cast         country  \
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...  United Kingdom
# 27  Adam Sandler, Kevin James, Chris Rock, David S...   United States
#
#             date_added  release_year rating   duration  \
# 8   September 24, 2021          2021  TV-14  9 Seasons
# 27  September 20, 2021          2010  PG-13    103 min
#
#                        listed_in  \
# 8   British TV Shows, Reality TV
# 27                      Comedies
#
#                                           description
# 8   A talented batch of amateur bakers face off in...
# 27  Mourning the loss of their beloved junior high...

# %% [markdown]
# Q. 10) In how many movies/shows, Tom Cruise was cast ?

# %%
df[(df['cast']=='Tom Cruise')].value_counts()
# Out:
# Series([], dtype: int64)

# %%
df_new=df.dropna()

# %%
df_new[df_new['cast'].str.contains('Tom Cruise')]
# Out:
#      show_id   type     title              director  \
# 341     s342  Movie  Magnolia  Paul Thomas Anderson
# 1254   s1255  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 341   John C. Reilly, Philip Baker Hall, Tom Cruise,...  United States
# 1254  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#           date_added  release_year rating duration  \
# 341   August 1, 2021          1999      R  189 min
# 1254   March 1, 2021          1988      R  134 min
#
#                        listed_in  \
# 341   Dramas, Independent Movies
# 1254      Classic Movies, Dramas
#
#                                             description
# 341   Through chance, history and divine interventio...
# 1254  Motivated by money, a selfish workaholic seeki...

# %% [markdown]
# Q. 11) What are the different Ratings defined by Netflix ?

# %%
df.rating.unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
df.rating.nunique()
# Out:
# 17

# %% [markdown]
# Q. 12.1) How many Movies got the 'TV-14' rating, in Canada ?

# %%
df[(df['type']=='Movie') & (df['rating']=='TV-14') & (df['country']=='Canada')]
# Out:
#      show_id   type                                        title  \
# 157     s158  Movie                                     Level 16
# 1279   s1280  Movie   Made You Look: A True Story About Fake Art
# 2769   s2770  Movie               There's Something in the Water
# 3424   s3425  Movie  Martin Matte: La vie, la mort...eh la la..!
# 5972   s5973  Movie                             #cats_the_mewvie
# 5973   s5974  Movie                                        #Roxy
# 6192   s6193  Movie                               At First Light
# 6537   s6538  Movie                   Counterfeiting in Suburbia
# 7334   s7335  Movie                            Long Time Running
# 7916   s7917  Movie                   Sadie's Last Days on Earth
# 7936   s7937  Movie                                   Sardaar ji
# 8178   s8179  Movie                  The Accountant of Auschwitz
# 8566   s8567  Movie                         The Wrong Babysitter
#
#                                     director  \
# ...

# %%
df[(df['type']=='Movie') & (df['rating']=='TV-14') & (df['country']=='Canada')].shape[0]
# Out:
# 13

# %% [markdown]
# Q. 12) How many TV Shows got the 'R' rating, after year 2018 ?

# %%
df[(df['release_year']>2018) & (df['type']=='TV Show') & (df['rating']=='R')]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# Q. 12) What is the maximum duration of a Movie/Show on Netflix ?

# %%
df[['minutes','unit']]=df['duration'].str.split(' ', expand=True)
df['minutes']=df['minutes'].fillna(0)
df['minutes'].isna().sum()
# Out:
# 0

# %%
df['minutes']=df.minutes.astype('float')
df['minutes'].max()
# Out:
# 312.0

# %%
df.minutes.head(5)
# Out:
# 0    90
# 1     2
# 2     1
# 3     1
# 4     2
# Name: minutes, dtype: object

# %% [markdown]
# Q. 13) Which individual country has the Highest No. of TV Shows ?

# %%
df.groupby('type').get_group('TV Show')['country'].value_counts().head(1)
# Out:
# United States    760
# Name: country, dtype: int64

# %%
df_TVshow=df[df['type']=='TV Show']
df_TVshow.country.value_counts().head(1)
# Out:
# United States    760
# Name: country, dtype: int64

# %% [markdown]
# Q. 15) How can we sort the dataset by Year ?

# %%
df.sort_values(['release_year']).head()
# Out:
#      show_id     type                                          title  \
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
# 7790   s7791    Movie                                 Prelude to War
# 8205   s8206    Movie                           The Battle of Midway
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8739   s8740    Movie             Why We Fight: The Battle of Russia
#
#                          director                       cast        country  \
# 4250                          NaN                        NaN            NaN
# 7790                  Frank Capra                        NaN  United States
# 8205                    John Ford  Henry Fonda, Jane Darwell  United States
# 8660                    John Ford                        NaN  United States
# 8739  Frank Capra, Anatole Litvak                        NaN  United States
#
#              date_added  release_year rating  duration  \
# ...

# %% [markdown]
# Q. 15) Find all the instances where: Category is 'Movie' and Type is 'Dramas' or Category is 'TV Show' & Type is 'Kids' TV'.

# %%
df[((df['type']=='Movie') & (df['listed_in']=='Dramas'))|((df['type']=='TV Show') & (df['listed_in']=="Kids' TV"))]
# Out:
#      show_id     type                                              title  \
# 34       s35  TV Show                            Tayo and Little Wizards
# 39       s40  TV Show                                       Chhota Bheem
# 65       s66  TV Show                                       Numberblocks
# 89       s90  TV Show                                        Mighty Raju
# 100     s101  TV Show                            Tobot Galaxy Detectives
# 111     s112  TV Show                                           Sharkdog
# 112     s113    Movie                                              Worth
# 123     s124  TV Show                                          Luv Kushh
# 129     s130    Movie                                 An Unfinished Life
# 142     s143    Movie                                    Freedom Writers
# 153     s154  TV Show                                         Kid-E-Cats
# 162     s163    Movie                                           Marshall
# ...

# %%
df.listed_in.unique()
# Out:
# array(['Documentaries', 'International TV Shows, TV Dramas, TV Mysteries',
#        'Crime TV Shows, International TV Shows, TV Action & Adventure',
#        'Docuseries, Reality TV',
#        'International TV Shows, Romantic TV Shows, TV Comedies',
#        'TV Dramas, TV Horror, TV Mysteries', 'Children & Family Movies',
#        'Dramas, Independent Movies, International Movies',
#        'British TV Shows, Reality TV', 'Comedies, Dramas',
#        'Crime TV Shows, Docuseries, International TV Shows',
#        'Dramas, International Movies',
#        'Children & Family Movies, Comedies',
#        'British TV Shows, Crime TV Shows, Docuseries',
#        'TV Comedies, TV Dramas', 'Documentaries, International Movies',
#        'Crime TV Shows, Spanish-Language TV Shows, TV Dramas',
#        'Thrillers',
#        'International TV Shows, Spanish-Language TV Shows, TV Action & Adventure',
#        'International TV Shows, TV Action & Adventure, TV Dramas',
# ...
